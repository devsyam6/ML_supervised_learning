# %%
import os
import mahotas as mh
from sklearn.preprocessing import scale
import numpy as np
from sklearn.model_selection import train_test_split

X=[]
y=[]

for dir_path,dir_names,filenames in os.walk('/home/jimbrootan/Desktop/ML_data/att_faces'):
#     print('directory path : \n',dir_path,dir_names,filenames)
#     print('directory names : \n',dir_names)
    print('directory filenames : \n',filenames)
    for fn in filenames:
        if fn[-3:]=='pgm':
            image_filename=os.path.join(dir_path,fn)
            data =scale(mh.imread(image_filename,as_grey=True).reshape(10304).astype('float32'))
            X.append(data)
#             print(data.shape)
#             print(data)
            y.append(dir_path)
X= np.array(X)

X_train,X_test,y_train,y_test=train_test_split(X,y)
# Out:
# directory filenames :
#  ['README']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# directory filenames :
#  ['3.pgm', '1.pgm', '7.pgm', '10.pgm', '5.pgm', '4.pgm', '6.pgm', '8.pgm', '2.pgm', '9.pgm']
# ...

# %%
'''Principal Component analysis'''

from sklearn.decomposition import PCA

pca=PCA(n_components=200)

X_train_reduced = pca.fit_transform(X_train)
X_test_reduced=pca.transform(X_test)
print("original Diamention of data: ",X_train.shape)
print("Reduced Diamention of data: ",X_train_reduced.shape)
print(X_test_reduced.shape)
# Out:
# original Diamention of data:  (300, 10304)
# Reduced Diamention of data:  (300, 200)
# (100, 200)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report

model=LogisticRegression()
model.fit(X_train_reduced,y_train)

'''CROSS VALIDATION SCORE'''

model_accuracy=cross_val_score(model,X_train_reduced,y_train)
print("Cross validation Accuracy:  ",np.mean(model_accuracy),model_accuracy)


predictions = model.predict(X_test_reduced)
print(classification_report(y_test,predictions))
# Out:
# /home/jimbrootan/anaconda3/envs/pythonds/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jimbrootan/anaconda3/envs/pythonds/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# /home/jimbrootan/anaconda3/envs/pythonds/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
